# %% [markdown]
# ## work book for Data Quest ML Calculus

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='darkgrid')

# %%
def f(x):
    return -(x**2) + (3 * x) -1

# %%
x = np.linspace(0, 3, 100)
x
# Out:
# array([0.        , 0.03030303, 0.06060606, 0.09090909, 0.12121212,
#        0.15151515, 0.18181818, 0.21212121, 0.24242424, 0.27272727,
#        0.3030303 , 0.33333333, 0.36363636, 0.39393939, 0.42424242,
#        0.45454545, 0.48484848, 0.51515152, 0.54545455, 0.57575758,
#        0.60606061, 0.63636364, 0.66666667, 0.6969697 , 0.72727273,
#        0.75757576, 0.78787879, 0.81818182, 0.84848485, 0.87878788,
#        0.90909091, 0.93939394, 0.96969697, 1.        , 1.03030303,
#        1.06060606, 1.09090909, 1.12121212, 1.15151515, 1.18181818,
#        1.21212121, 1.24242424, 1.27272727, 1.3030303 , 1.33333333,
#        1.36363636, 1.39393939, 1.42424242, 1.45454545, 1.48484848,
#        1.51515152, 1.54545455, 1.57575758, 1.60606061, 1.63636364,
#        1.66666667, 1.6969697 , 1.72727273, 1.75757576, 1.78787879,
#        1.81818182, 1.84848485, 1.87878788, 1.90909091, 1.93939394,
#        1.96969697, 2.        , 2.03030303, 2.06060606, 2.09090909,
# ...

# %%
y = f(x)
y
# Out:
# array([-1.        , -0.91000918, -0.82185491, -0.73553719, -0.65105601,
#        -0.56841139, -0.48760331, -0.40863177, -0.33149679, -0.25619835,
#        -0.18273646, -0.11111111, -0.04132231,  0.02662994,  0.09274564,
#         0.15702479,  0.2194674 ,  0.28007346,  0.33884298,  0.39577594,
#         0.45087236,  0.50413223,  0.55555556,  0.60514233,  0.65289256,
#         0.69880624,  0.74288338,  0.78512397,  0.82552801,  0.8640955 ,
#         0.90082645,  0.93572084,  0.9687787 ,  1.        ,  1.02938476,
#         1.05693297,  1.08264463,  1.10651974,  1.12855831,  1.14876033,
#         1.1671258 ,  1.18365473,  1.19834711,  1.21120294,  1.22222222,
#         1.23140496,  1.23875115,  1.24426079,  1.24793388,  1.24977043,
#         1.24977043,  1.24793388,  1.24426079,  1.23875115,  1.23140496,
#         1.22222222,  1.21120294,  1.19834711,  1.18365473,  1.1671258 ,
#         1.14876033,  1.12855831,  1.10651974,  1.08264463,  1.05693297,
# ...

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# The challenge is to brainstorm the max height and time it occurred. My answer is  if the y int is 0,0 then time is 1.5 and the max height is approx 1.5

# %% [markdown]
# ## Linear Functions
# All linear functions can be written as y = mx+b
# we will use the linear functions y = 3x + 1

# %%
from ipywidgets import interact, interactive, Dropdown, FloatSlider, Button, Output

@interact(m=(-5, 5, 0.1), b=(-10, 10, 0.1))
def plot_linear(m=3, b=1):
    lin_xs = np.linspace(-5, 5, 100)
    lin_ys = m * lin_xs + b
    plt.figure(figsize=(8, 6))
    plt.plot(lin_xs, lin_ys, linewidth=2)
    plt.grid(True, alpha=0.3)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title(f'Linear Function: y = {m}x + {b}')
    plt.axhline(y=0, color='k', linewidth=0.5)
    plt.axvline(x=0, color='k', linewidth=0.5)
    plt.show()
# Out:
# interactive(children=(FloatSlider(value=3.0, description='m', max=5.0, min=-5.0), FloatSlider(value=1.0, descr…

# %% [markdown]
# In a linear function m is the slope and b is the y intercept
# $$m = \frac{\Delta y}{\Delta x} = \frac{y_2 - y_1}{x_2 - x_1}$$

# %%
def slope(x1, y1, x2, y2):
    return (y2-y1) / (x2-x1)
slope_two = slope(5, 16, -1, -2)
slope_one = slope(0,1,4,13)

# %%
def draw_secant(x_values):
    x = np.linspace(-20,30,100)
    y = -1*(x**2) + x*3 - 1
    plt.plot(x,y)
    # Add your code here.
    # determine y values for x
    # get slope for points
    # calc y intercept
    #plot secant line in green
    ys = []
    for val in x_values:
        y = -1*(val**2)+ val*3 -1
        ys.append(y)
    curr_slope = slope(x_values[0], ys[0], x_values[1], ys[1])
    b = ys[0] - curr_slope * x_values[0]
    secant = curr_slope * x + b
    print(curr_slope)
    print(ys)
    plt.plot(x, secant, 'g')


    plt.show()

draw_secant([3,15.1])
# Out:
# -15.099999999999998
# [-1, -183.70999999999998]

# %%
draw_secant([3,10])
# Out:
# -10.0
# [-1, -71]

# %%
draw_secant([1, 5])
# Out:
# -3.0
# [1, -11]

# %% [markdown]
# Look up np.linspace
# np.linspace is a function within the NumPy library in Python used to generate an array of evenly spaced numbers over a specified interval. The np prefix is a common convention for importing NumPy as import numpy as np.
# Key features and parameters of np.linspace:
# start: The starting value of the sequence.
# stop: The end value of the sequence. By default, this value is included in the array.
# num: The number of samples (or elements) to generate within the interval. The default value is 50.
